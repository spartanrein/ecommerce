# %%
import pandas as pd

# %%
df = pd.read_csv("shoes_cleaned.csv")

# %%
df2 = pd.read_csv('amazon_clothing_shuffled.csv')

# %%
df2.head(100)
# Out:
#                                          product_name                   brand  \
# 0                                  blossom bikini top                     NaN
# 1   pack plain jane wide calf compression socks mm...                    LISH
# 2         high rise destroyed cropped skinny jeans kc                 KAN CAN
# 3   low cut compression socks anti smell hiking at...                     J&Q
# 4   washed ripped hole mini jean shorts hot denim ...             FreelyWomen
# 5                     short sleeve fashion polo shirt                     NaN
# 6   fishnet seamless full footed panty hose tights...             ToBeInStyle
# 7   swimsuit hipster bikini bottoms full coverage ...                 SHEKINI
# 8   comfy pants ultra soft irregular rainbow print...                   TSWRK
# 9   sytx lapel long sleeve patch slim fit plaid bl...      SYTX-women clothes
# 10  high waisted super stretchy skinny denim jeggi...                   Jvini
# ...

# %%
df = pd.concat([df,df2])

# %%
df.to_csv('amazon_data_shuffled.csv')

# %%
from scikit
df = shuffle(df, random_state = 100)
